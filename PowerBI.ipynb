# %% [markdown]
# <a href="https://colab.research.google.com/github/clumsycoder42525/PowerBI_Dashboards/blob/main/PowerBI.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df=pd.read_excel("/content/Mobile Sales Data.xlsx")

# %%
df.size
# Out:
# 53690

# %%
df.head(6)
# Out:
#    Transaction ID  Day  Month  Year  Day Name    Brand  Units Sold  \
# 0               1    9     10  2021       Sat   Xiaomi           6
# 1               2    9     10  2021  Saturday     Vivo           6
# 2               3    9     10  2021  Saturday     Vivo           8
# 3               4   10     10  2021    Sunday   Xiaomi           5
# 4               5   10     10  2021    Sunday  OnePlus           3
# 5               6   10     10  2021    Sunday  Samsung           3
#
#    Price Per Unit     Customer Name  Customer Age       City Payment Method  \
# 0        10174.70      Lalita Ahuja            38   Ludhiana            UPI
# 1        10565.19      Sneha Sharma            37      Delhi    Credit Card
# 2        58527.58  Radha Srivastava            40     Mumbai            UPI
# 3        25563.98     Bhavana Arora            21     Mumbai    Credit Card
# 4        48168.02       Sneha Mehta            38  Gorakhpur           Cash
# ...

# %%
def sample_date(a, b, c):
  return f"{a}-{b}-{c}"

# %%
df["Date"] = list(map(sample_date, df["Day"], df["Month"], df["Year"]))

# %%
import pandas as pd

df["Date"] = pd.to_datetime(df["Date"], format="%d-%m-%Y")

# Ab data type check karein
print(df["Date"].dtype)
# Out:
# datetime64[ns]

# %%
df["Date"]
# Out:
# 0      2021-10-09
# 1      2021-10-09
# 2      2021-10-09
# 3      2021-10-10
# 4      2021-10-10
#           ...
# 3830   2024-10-07
# 3831   2024-10-08
# 3832   2024-10-08
# 3833   2024-10-08
# 3834   2024-10-08
# Name: Date, Length: 3835, dtype: datetime64[ns]

# %%
import pandas as pd
file_path = 'your_data.csv'
df.to_csv(file_path, index=False)
print(f"DataFrame saved to '{file_path}'")
from google.colab import files
files.download(file_path)
# Out:
# DataFrame saved to 'your_data.csv'
